# %%
### 문제 요구 사항 
- 좌표 압축을 적용해서 좌표의 압축 결과를 출력하는 것 

좌표 압축이란 ? 
좌표 압축은 알고리즘이라기보다 테크닉에 가깝다.
### 풀이과정 
- 주어진 수를 정렬한 후 인덱스를 구해서 딕셔너리 형태로 저장한다. 
- 저장된 딕셔너리와 처음의 리스트와 비교해서 값의 인덱스 값을 구해주면 된다. 
### 잘한 부분 및 개선할 부분 
- 문제를 스스로 이해해보려 노력한 것 
- 문제를 제대로 이해하지 못했다. 
### 알게 된 부분 
- 풀이 방식은 의외로 단순하다. 더 많은 문제를 풀어봄으로써 컴퓨터적인 사고를 해야 한다는 것 
- dictinary 와 set을 이용해서 데이터를 변형시키는 방법을 배울 수 있었다. 
- set 은 데이터의 요소 중복값을 없애준다는것을 기억하자 그러나 순서는 장담할 수 없다. 
- dictionary[key] = value 라는 것 ! 잘 이용해야 한다. 
### 향후 계획 
    정렬문제 한번 skimming 및 정리 필요

# %%
import sys 
input = sys.stdin.readline

def t(): 
    sangeun_in = int(input())
    sang_arr = list(map(int, input().split()))

    N = int(input())
    ox_arr = list(map(int, input().split()))


    arr = list() 
    for i in ox_arr:
        if i in sang_arr:
            arr.append(int(1))
        else :
            arr.append(int(0))
            
t() 

# 시간초과 
# 함수를 사용하면 그나마 통과를 한다는데 ..... 그렇지만 
# 이진탐색으로 구현해봐야한다.

# %%
print(arr)
# Out:
# [1, 0, 0, 1, 1, 0, 0, 1]

# %%
# dict 로 푸는 방법

# %%
# 이진탐색 구현
